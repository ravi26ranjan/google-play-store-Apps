# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import dataset
data = pd.read_csv('googleplaystore.csv')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
len(data[data.duplicated()])
# Out:
# 483

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
# remove duplicate data
data.drop_duplicates(inplace = True)

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
# Checking null values
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data_df = data.copy()

# %%
data_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
data_df['Rating'].fillna(0,inplace=True)

# %%
data_df.describe()
# Out:
#              Rating
# count  10358.000000
# mean       3.596988
# std        1.545008
# min        0.000000
# 25%        3.700000
# 50%        4.200000
# 75%        4.500000
# max       19.000000

# %%
data_df.describe(include='all')
# Out:
#            App Category        Rating Reviews                Size    Installs  \
# count    10358    10358  10358.000000   10358               10358       10358
# unique    9660       34           NaN    6002                 462          22
# top     ROBLOX   FAMILY           NaN       0  Varies with device  1,000,000+
# freq         9     1943           NaN     593                1526        1488
# mean       NaN      NaN      3.596988     NaN                 NaN         NaN
# std        NaN      NaN      1.545008     NaN                 NaN         NaN
# min        NaN      NaN      0.000000     NaN                 NaN         NaN
# 25%        NaN      NaN      3.700000     NaN                 NaN         NaN
# 50%        NaN      NaN      4.200000     NaN                 NaN         NaN
# 75%        NaN      NaN      4.500000     NaN                 NaN         NaN
# max        NaN      NaN     19.000000     NaN                 NaN         NaN
#
# ...

# %%
# Columns in our data
data_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data_df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10358, dtype: object

# %% [markdown]
# ### Total number of App containing Astrology

# %%
# data_df['App'].str.contains('Astrology',case='False').sum()
# This can also be done by below method
len(data[data_df['App'].str.contains('Astrology',case='False')])
# Out:
# 3

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %% [markdown]
# ### Analysis Of Rating of Apps

# %%
data_df['Rating'].sort_values(ascending=False)
# Out:
# 10472    19.0
# 9701      5.0
# 6275      5.0
# 9056      5.0
# 6363      5.0
#          ...
# 5250      0.0
# 9648      0.0
# 5249      0.0
# 5247      0.0
# 6445      0.0
# Name: Rating, Length: 10358, dtype: float64

# %%
# As we can see that one row contains values of 19 and next smaller value is 5 , so this might be a error. So we will remove it

# %%
Del_index = data_df[ data_df['Rating'] == 19].index
data_df.drop(Del_index , inplace=True)

# %% [markdown]
# ### Average Rating of Apps

# %%
data_df['Rating'].mean()
# Out:
# 3.595500627594864

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %% [markdown]
# ### Number of Unique Category

# %%
data_df['Category'].nunique()
# Out:
# 33

# %%
# Average Rating of Apps ccategory wise
data_df.groupby('Category')['Rating'].mean()
# Out:
# Category
# ART_AND_DESIGN         4.156923
# AUTO_AND_VEHICLES      3.598824
# BEAUTY                 3.390566
# BOOKS_AND_REFERENCE    3.345652
# BUSINESS               2.594145
# COMICS                 4.016667
# COMMUNICATION          3.482240
# DATING                 3.221939
# EDUCATION              4.342308
# ENTERTAINMENT          4.136036
# EVENTS                 3.118750
# FAMILY                 3.705816
# FINANCE                3.634444
# FOOD_AND_DRINK         3.559677
# GAME                   4.101784
# HEALTH_AND_FITNESS     3.648693
# HOUSE_AND_HOME         3.540000
# LIBRARIES_AND_DEMO     3.195294
# LIFESTYLE              3.349330
# MAPS_AND_NAVIGATION    3.667153
# MEDICAL                3.095833
# NEWS_AND_MAGAZINES     3.346591
# PARENTING              3.583333
# PERSONALIZATION        3.462629
# PHOTOGRAPHY            3.949068
# PRODUCTIVITY           3.448157
# SHOPPING               3.833929
# SOCIAL                 3.707857
# SPORTS                 3.442735
# ...

# %% [markdown]
# ### Category having Highest Rating

# %%
data_df.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# EDUCATION              4.342308
# ART_AND_DESIGN         4.156923
# ENTERTAINMENT          4.136036
# GAME                   4.101784
# COMICS                 4.016667
# PHOTOGRAPHY            3.949068
# WEATHER                3.881707
# SHOPPING               3.833929
# VIDEO_PLAYERS          3.715429
# SOCIAL                 3.707857
# FAMILY                 3.705816
# MAPS_AND_NAVIGATION    3.667153
# HEALTH_AND_FITNESS     3.648693
# FINANCE                3.634444
# AUTO_AND_VEHICLES      3.598824
# PARENTING              3.583333
# FOOD_AND_DRINK         3.559677
# TRAVEL_AND_LOCAL       3.541350
# HOUSE_AND_HOME         3.540000
# TOOLS                  3.524081
# COMMUNICATION          3.482240
# PERSONALIZATION        3.462629
# PRODUCTIVITY           3.448157
# SPORTS                 3.442735
# BEAUTY                 3.390566
# LIFESTYLE              3.349330
# NEWS_AND_MAGAZINES     3.346591
# BOOKS_AND_REFERENCE    3.345652
# DATING                 3.221939
# ...

# %%
## Apps having Rating 5 star

# %%
data_df[data_df['Rating']==5.0]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
### Count of the app having Rating 5 star
len(data_df[data_df['Rating']==5.0])
# Out:
# 271

# %% [markdown]
# ### Average Values of Reviews

# %%
data_df['Reviews'].dtype
# Out:
# dtype('O')

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
# This is an object data type so we need to change to float to apply mathematical operation on it

# %%
data_df['Reviews']=data_df['Reviews'].astype('float')

# %%
data_df['Reviews'].dtype
# Out:
# dtype('float64')

# %%
data_df['Reviews'].mean()
# Out:
# 405904.6106015255

# %% [markdown]
# ### App having Max reviews

# %%
data_df[data_df['Reviews'].max()==data_df['Reviews']]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %% [markdown]
# ### Top 5 Apps Having Max Reviews

# %%
# index = 
data_df[data_df['Reviews'].sort_values(ascending=False)]
# .index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 # index =
# ----> 2 data_df[data_df['Reviews'].sort_values(ascending=False)]
#       3 # .index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
data_df.loc[index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data_df.loc[index]
#
# NameError: name 'index' is not defined

# %% [markdown]
# ### Total Number of Free AND paid Apps

# %%
data_df['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
data_df['Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data_df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free    3.610291
# Paid    3.414771
# Name: Rating, dtype: float64

# %% [markdown]
# ### Top 5 Apps Having Maximum Download

# %%
data_df['Installs'].dtype
# Out:
# dtype('O')

# %% [markdown]
# - `We need to convert the Installs column to float datatype`
# - `To convert into float we need to remove "," and "+" signs from our column `

# %%
data_df['Installs_1'] = data_df['Installs'].str.replace(',','')

# %%
data_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_df['Installs_1'] = data_df['Installs_1'].str.replace('+','')
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_11600\4283637146.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_df['Installs_1'] = data_df['Installs_1'].str.replace('+','')

# %%
data_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_df['Installs_1'] = data_df['Installs_1'].astype('int')

# %%
data_df['Installs_1'].dtype
# Out:
# dtype('int32')

# %%
 data_df['Installs_1'].sort_values(ascending=False)
# Out:
# 341     1000000000
# 3928    1000000000
# 451     1000000000
# 3996    1000000000
# 1700    1000000000
#            ...
# 9719             0
# 8871             0
# 9337             0
# 5486             0
# 6692             0
# Name: Installs_1, Length: 10357, dtype: int32

# %%
index = data_df['Installs_1'].sort_values(ascending=False).head().index

# %%
data_df.iloc[index]
# Out:
#                                              App         Category  Rating  \
# 374   Antillean Gold Telegram (original version)    COMMUNICATION     4.4
# 4382                            Cops N Robbers 2             GAME     4.1
# 498        Free Dating App & Flirt Chat - Cheers           DATING     4.4
# 4451                         Android P Home KLWP  PERSONALIZATION     0.0
# 1918                                  Helix Jump             GAME     4.2
#
#         Reviews  Size      Installs  Type  Price Content Rating  \
# 374      2939.0   17M      100,000+  Free      0       Everyone
# 4382    63680.0   46M    1,000,000+  Free      0   Everyone 10+
# 498       667.0   27M       10,000+  Free      0     Mature 17+
# 4451        0.0  2.1M            5+  Paid  $1.49       Everyone
# 1918  1500999.0   33M  100,000,000+  Free      0       Everyone
#
#                Genres    Last Updated      Current Ver Android Ver  Installs_1
# ...

# %%
data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object
